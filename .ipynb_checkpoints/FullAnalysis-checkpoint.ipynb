# %% [markdown]
# # Modeling Variables of non-interest
# Before we set up our path model, we need to account for head size, sex, and scanner sequence.

# %%
library(gdata)
library(ggplot2)
setwd('/home/camachocm2/Analysis/aggregate_anats/results/')
data <- read.csv('/home/camachocm2/Analysis/aggregate_anats/results/combined_data_k2_20180710.csv')
print(colnames(data))
#complete_data <-data [which(data$totPutamen>0 & data$totPallidum>0 & data$totCaudate>0 & data$totAccumbens.area>0),]
complete_data <-data [which(data$totPutamen>0 & data$totPallidum>0),]
# Out:
# gdata: read.xls support for 'XLS' (Excel 97-2004) files ENABLED.
#
# gdata: read.xls support for 'XLSX' (Excel 2007+) files ENABLED.
#
# Attaching package: ‘gdata’
#
# The following object is masked from ‘package:stats’:
#
#     nobs
#
# The following object is masked from ‘package:utils’:
#
#     object.size
#
# The following object is masked from ‘package:base’:
#
#     startsWith
#  [1] "X"                           "freesurferID"
#  [3] "eTIV"                        "Left.Caudate"
#  [5] "Left.Putamen"                "Left.Pallidum"
#  [7] "Left.Accumbens.area"         "Left.Thalamus.Proper"
#  [9] "Right.Caudate"               "Right.Putamen"
# [11] "Right.Pallidum"              "Right.Accumbens.area"
# [13] "Right.Thalamus.Proper"       "activity_level"
# [15] "anger_frustration"           "attention_focusing"
# [17] "discomfort"                  "soothability"
# [19] "fear"                        "high_intensity_pleasure"
# [21] "impulsivity"                 "inhibitory_control"
# [23] "low_intensity_pleasure"      "perceptual_sensitivity"
# [25] "sadness"                     "shyness"
# [27] "activity_level_std"          "anger_frustration_std"
# [29] "attention_focusing_std"      "discomfort_std"
# [31] "soothability_std"            "fear_std"
# [33] "high_intensity_pleasure_std" "impulsivity_std"
# [35] "inhibitory_control_std"      "low_intensity_pleasure_std"
# [37] "perceptual_sensitivity_std"  "sadness_std"
# [39] "shyness_std"                 "kmgroup"
# [41] "SubjectID"                   "Study"
# [43] "Sequence.Version"            "in_analysis"
# [45] "Same.Kid.as."                "Dx_Group"
# [47] "Age_yrs"                     "Age_mos"
# [49] "male"                        "clinical"
# [51] "smd"                         "adhd"
# [53] "meds"                        "internalizing"
# [55] "externalizing"               "totPutamen"
# [57] "totPutamen_std"              "totPallidum"
# [59] "totPallidum_std"             "totCaudate"
# [61] "totCaudate_std"              "totAccumbens.area"
# [63] "totAccumbens.area_std"       "internalizing_std"
# [65] "externalizing_std"

# %%
lmodel <- lm(totPutamen_std ~ eTIV + male+ Study, data=complete_data)
complete_data$res_putamen <- resid(lmodel)
lmodel <- lm(totPallidum_std ~ 1 + eTIV + male+ Study, data=complete_data)
complete_data$res_pall <- resid(lmodel)
#lmodel <- lm(totCaudate_std ~ 1 + eTIV  + male+ Sequence.Version, data=complete_data)
#complete_data$res_caud <- resid(lmodel)
#lmodel <- lm(totAccumbens.area_std ~ 1 + eTIV + male+ Sequence.Version, data=complete_data)
#complete_data$res_nacc <- resid(lmodel)

irr_group <- complete_data[which(complete_data$kmgroup==0),]

# %% [markdown]
# ## Modeling Variables of interest

# %%
full_model <- manova(cbind(res_putamen, res_pall) ~ Age_yrs + kmgroup + internalizing + externalizing, data=complete_data)
summary(full_model)
summary.aov(full_model)

full_model <- manova(cbind(res_putamen, res_pall) ~ Age_yrs + kmgroup + externalizing + kmgroup*externalizing + kmgroup*Age_yrs, data=complete_data)
summary(full_model)
summary.aov(full_model)
# Out:
#                Df   Pillai approx F num Df den Df  Pr(>F)
# Age_yrs         1 0.037742   2.0788      2    106 0.13015
# kmgroup         1 0.059887   3.3762      2    106 0.03789 *
# internalizing   1 0.004958   0.2641      2    106 0.76841
# externalizing   1 0.073804   4.2233      2    106 0.01719 *
# Residuals     107
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#  Response res_putamen :
#                Df Sum Sq Mean Sq F value  Pr(>F)
# Age_yrs         1  0.917 0.91730  1.7033 0.19466
# kmgroup         1  2.036 2.03598  3.7805 0.05448 .
# internalizing   1  0.024 0.02426  0.0450 0.83233
# externalizing   1  0.075 0.07543  0.1401 0.70896
# Residuals     107 57.624 0.53854
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Response res_pall :
#                Df Sum Sq Mean Sq F value  Pr(>F)
# Age_yrs         1  1.558 1.55786  3.9715 0.04882 *
# kmgroup         1  2.300 2.29969  5.8626 0.01715 *
# internalizing   1  0.112 0.11160  0.2845 0.59487
# externalizing   1  2.324 2.32363  5.9236 0.01659 *
# Residuals     107 41.972 0.39226
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#                        Df   Pillai approx F num Df den Df  Pr(>F)
# Age_yrs                 1 0.036593   1.9941      2    105 0.14126
# kmgroup                 1 0.058791   3.2793      2    105 0.04155 *
# externalizing           1 0.005783   0.3054      2    105 0.73752
# kmgroup:externalizing   1 0.000034   0.0018      2    105 0.99822
# Age_yrs:kmgroup         1 0.022855   1.2280      2    105 0.29706
# Residuals             106
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#  Response res_putamen :
#                        Df Sum Sq Mean Sq F value  Pr(>F)
# Age_yrs                 1  0.917 0.91730  1.7141 0.19328
# kmgroup                 1  2.036 2.03598  3.8046 0.05375 .
# externalizing           1  0.000 0.00000  0.0000 0.99945
# kmgroup:externalizing   1  0.000 0.00013  0.0002 0.98751
# Age_yrs:kmgroup         1  1.000 0.99962  1.8680 0.17460
# Residuals             106 56.724 0.53513
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Response res_pall :
#                        Df Sum Sq Mean Sq F value  Pr(>F)
# Age_yrs                 1  1.558 1.55786  3.7369 0.05589 .
# kmgroup                 1  2.300 2.29969  5.5164 0.02069 *
# externalizing           1  0.211 0.21065  0.5053 0.47874
# kmgroup:externalizing   1  0.001 0.00087  0.0021 0.96364
# Age_yrs:kmgroup         1  0.007 0.00662  0.0159 0.89998
# Residuals             106 44.189 0.41688
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
options(repr.plot.width=4, repr.plot.height=3)
p <- ggplot(data=complete_data, aes(x=Age_yrs, y=res_putamen, group=kmgroup, color=kmgroup)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)

p <- ggplot(data=complete_data, aes(x=Age_yrs, y=res_pall, group=kmgroup, color=kmgroup)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)

p <- ggplot(data=complete_data, aes(x=Age_yrs, y=externalizing, group=kmgroup, color=kmgroup)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)

p <- ggplot(data=complete_data, aes(x=Age_yrs, y=internalizing, group=kmgroup, color=kmgroup)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)

# %%
full_model <- manova(cbind(res_putamen, res_pall, res_caud, res_nacc) ~ Age_yrs + Dx_Group + Age_yrs*Dx_Group, data=complete_data)
summary(full_model)
summary.aov(full_model)

# %%
options(repr.plot.width=4, repr.plot.height=3)
p <- ggplot(data=complete_data, aes(x=Age_yrs, y=res_putamen, group=Dx_Group, color=Dx_Group)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)

p <- ggplot(data=complete_data, aes(x=Age_yrs, y=res_pall, group=Dx_Group, color=Dx_Group)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)

# %%
full_model <- manova(cbind(internalizing, externalizing) ~ res_pall + res_putamen + kmgroup, data=complete_data)
summary(full_model)
summary.aov(full_model)

# %%
p <- ggplot(data=complete_data, aes(x=kmgroup, y=res_pall, group=kmgroup, color=kmgroup)) + geom_boxplot()
show(p)
p <- ggplot(data=complete_data, aes(x=kmgroup, y=internalizing, group=kmgroup, color=kmgroup)) + geom_boxplot()
show(p)
p <- ggplot(data=complete_data, aes(x=kmgroup, y=externalizing, group=kmgroup, color=kmgroup)) + geom_boxplot()
show(p)
p <- ggplot(data=complete_data, aes(x=res_pall, y=internalizing, group=kmgroup, color=kmgroup)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)
p <- ggplot(data=complete_data, aes(x=res_pall, y=externalizing, group=kmgroup, color=kmgroup)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)

# %%
full_model <- manova(cbind(internalizing, externalizing) ~ Age_yrs + kmgroup + res_putamen + res_pall + kmgroup*res_putamen + kmgroup*res_pall, data=complete_data)
summary(full_model)
summary.aov(full_model)

# %%
p <- ggplot(data=complete_data, aes(x=res_pall, y=internalizing_std, group=Dx_Group, color=Dx_Group)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)

# %% [markdown]
# # Structural Equation Modeling

# %%
library(corrplot)
cor_res<-cor(cbind(complete_data$res_pall,complete_data$res_putamen,complete_data$internalizing,
                   complete_data$externalizing,complete_data$kmgroup), use='complete.obs')
cor_res
corrplot(cor_res, type='upper')
# Out:
# corrplot 0.84 loaded
#      [,1]        [,2]        [,3]        [,4]        [,5]
# [1,]  1.00000000  0.45424447 -0.02262116  0.11742127 -0.1723157
# [2,]  0.45424447  1.00000000  0.04346562  0.05764697 -0.1508553
# [3,] -0.02262116  0.04346562  1.00000000  0.87957209 -0.3379290
# [4,]  0.11742127  0.05764697  0.87957209  1.00000000 -0.5076268
# [5,] -0.17231573 -0.15085532 -0.33792898 -0.50762676  1.0000000
# Plot with title “”

# %%
library(corrplot)
cor_res<-cor(cbind(irr_group$res_pall,irr_group$res_putamen,irr_group$internalizing,
                   irr_group$externalizing), use='complete.obs')
cor_res
corrplot(cor_res, type='upper')
# Out:
#      [,1]        [,2]        [,3]        [,4]
# [1,]  1.00000000  0.43814671 -0.19516984  0.02002893
# [2,]  0.43814671  1.00000000 -0.01323849 -0.03369927
# [3,] -0.19516984 -0.01323849  1.00000000  0.85014306
# [4,]  0.02002893 -0.03369927  0.85014306  1.00000000
# Plot with title “”

# %%
library(lavaan)

model <- 'externalizing_std ~ c*res_pall
        
          kmgroup ~ a*res_pall
          externalizing_std ~ b*kmgroup
         
          ab:=a*b
          total := c + (a*b)
          '
fit <- sem(model, data=complete_data)
summary(fit)
coef(fit)
