# %% [markdown]
# # Modeling Variables of non-interest
# Before we set up our path model, we need to account for head size, sex, and scanner sequence.

# %%
library(gdata)
library(ggplot2)
setwd('/home/camachocm2/Analysis/aggregate_anats/results/')
data <- read.csv('/home/camachocm2/Analysis/aggregate_anats/results/combined_data_k2_20180710.csv')
print(colnames(data))
#complete_data <-data [which(data$totPutamen>0 & data$totPallidum>0 & data$totCaudate>0 & data$totAccumbens.area>0),]
complete_data <-data [which(data$totPutamen>0 & data$totPallidum>0),]
# Out:
#  [1] "X"                           "freesurferID"
#  [3] "eTIV"                        "Left.Caudate"
#  [5] "Left.Putamen"                "Left.Pallidum"
#  [7] "Left.Accumbens.area"         "Left.Thalamus.Proper"
#  [9] "Right.Caudate"               "Right.Putamen"
# [11] "Right.Pallidum"              "Right.Accumbens.area"
# [13] "Right.Thalamus.Proper"       "activity_level"
# [15] "anger_frustration"           "attention_focusing"
# [17] "discomfort"                  "soothability"
# [19] "fear"                        "high_intensity_pleasure"
# [21] "impulsivity"                 "inhibitory_control"
# [23] "low_intensity_pleasure"      "perceptual_sensitivity"
# [25] "sadness"                     "shyness"
# [27] "activity_level_std"          "anger_frustration_std"
# [29] "attention_focusing_std"      "discomfort_std"
# [31] "soothability_std"            "fear_std"
# [33] "high_intensity_pleasure_std" "impulsivity_std"
# [35] "inhibitory_control_std"      "low_intensity_pleasure_std"
# [37] "perceptual_sensitivity_std"  "sadness_std"
# [39] "shyness_std"                 "kmgroup"
# [41] "SubjectID"                   "Study"
# [43] "Sequence.Version"            "in_analysis"
# [45] "Same.Kid.as."                "Dx_Group"
# [47] "Age_yrs"                     "Age_mos"
# [49] "male"                        "clinical"
# [51] "smd"                         "adhd"
# [53] "meds"                        "internalizing"
# [55] "externalizing"               "totPutamen"
# [57] "totPutamen_std"              "totPallidum"
# [59] "totPallidum_std"             "totCaudate"
# [61] "totCaudate_std"              "totAccumbens.area"
# [63] "totAccumbens.area_std"       "internalizing_std"
# [65] "externalizing_std"

# %%
lmodel <- lm(totPutamen_std ~ eTIV + male+ Study + Age_yrs, data=complete_data)
complete_data$res_putamen <- resid(lmodel)
lmodel <- lm(totPallidum_std ~ 1 + eTIV + male+ Study + Age_yrs, data=complete_data)
complete_data$res_pall <- resid(lmodel)
#lmodel <- lm(totCaudate_std ~ 1 + eTIV  + male+ Sequence.Version, data=complete_data)
#complete_data$res_caud <- resid(lmodel)
#lmodel <- lm(totAccumbens.area_std ~ 1 + eTIV + male+ Sequence.Version, data=complete_data)
#complete_data$res_nacc <- resid(lmodel)

# %% [markdown]
# ## Modeling Variables of interest

# %%
full_model <- manova(cbind(res_putamen, res_pall) ~ kmgroup + Age_yrs*kmgroup, data=complete_data)
summary(full_model)
summary.aov(full_model)
# Out:
#                  Df   Pillai approx F num Df den Df Pr(>F)
# kmgroup           1 0.041161  2.29665      2    107 0.1055
# Age_yrs           1 0.001194  0.06397      2    107 0.9381
# kmgroup:Age_yrs   1 0.031217  1.72392      2    107 0.1833
# Residuals       108
#  Response res_putamen :
#                  Df Sum Sq Mean Sq F value  Pr(>F)
# kmgroup           1  0.973 0.97331  1.8483 0.17681
# Age_yrs           1  0.027 0.02711  0.0515 0.82093
# kmgroup:Age_yrs   1  1.598 1.59842  3.0354 0.08431 .
# Residuals       108 56.872 0.52659
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Response res_pall :
#                  Df Sum Sq Mean Sq F value  Pr(>F)
# kmgroup           1  1.796 1.79649  4.3737 0.03884 *
# Age_yrs           1  0.050 0.05004  0.1218 0.72774
# kmgroup:Age_yrs   1  0.009 0.00857  0.0209 0.88539
# Residuals       108 44.361 0.41075
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
options(repr.plot.width=4, repr.plot.height=3)
p <- ggplot(data=complete_data, aes(x=Age_yrs, y=res_putamen, group=kmgroup, color=kmgroup)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)

p <- ggplot(data=complete_data, aes(x=Age_yrs, y=res_pall, group=kmgroup, color=kmgroup)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)
# Out:
# plot without title
# plot without title

# %%
full_model <- manova(cbind(res_putamen, res_pall, res_caud, res_nacc) ~ Age_yrs + Dx_Group + Age_yrs*Dx_Group, data=complete_data)
summary(full_model)
summary.aov(full_model)
# Out:
# Error in cbind(res_putamen, res_pall, res_caud, res_nacc): object 'res_caud' not found
# Traceback:
#
# 1. manova(cbind(res_putamen, res_pall, res_caud, res_nacc) ~ Age_yrs +
#  .     Dx_Group + Age_yrs * Dx_Group, data = complete_data)
# 2. eval(fcall, parent.frame())
# 3. eval(fcall, parent.frame())
# 4. stats::aov(cbind(res_putamen, res_pall, res_caud, res_nacc) ~
#  .     Age_yrs + Dx_Group + Age_yrs * Dx_Group, data = complete_data)
# 5. eval(lmcall, parent.frame())
# 6. eval(lmcall, parent.frame())
# 7. stats::lm(formula = cbind(res_putamen, res_pall, res_caud, res_nacc) ~
#  .     Age_yrs + Dx_Group + Age_yrs * Dx_Group, data = complete_data,
#  .     singular.ok = TRUE)
# 8. eval(mf, parent.frame())
# 9. eval(mf, parent.frame())
# 10. stats::model.frame(formula = cbind(res_putamen, res_pall, res_caud,
#   .     res_nacc) ~ Age_yrs + Dx_Group + Age_yrs * Dx_Group, data = complete_data,
#   .     drop.unused.levels = TRUE)
# 11. model.frame.default(formula = cbind(res_putamen, res_pall, res_caud,
#   .     res_nacc) ~ Age_yrs + Dx_Group + Age_yrs * Dx_Group, data = complete_data,
#   .     drop.unused.levels = TRUE)
# 12. eval(predvars, data, env)
# 13. eval(predvars, data, env)
# 14. cbind(res_putamen, res_pall, res_caud, res_nacc)

# %%
options(repr.plot.width=4, repr.plot.height=3)
p <- ggplot(data=complete_data, aes(x=Age_yrs, y=res_putamen, group=Dx_Group, color=Dx_Group)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)

p <- ggplot(data=complete_data, aes(x=Age_yrs, y=res_pall, group=Dx_Group, color=Dx_Group)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)
# Out:
# plot without title
# plot without title

# %%
full_model <- manova(cbind(internalizing, externalizing) ~ Age_yrs + kmgroup + res_pall + res_putamen + kmgroup*res_putamen + Age_yrs*kmgroup + kmgroup*res_pall, data=complete_data)
summary(full_model)
summary.aov(full_model)
# Out:
#                      Df  Pillai approx F num Df den Df    Pr(>F)
# Age_yrs               1 0.07840    4.381      2    103   0.01492 *
# kmgroup               1 0.38928   32.826      2    103 9.354e-12 ***
# res_pall              1 0.06002    3.289      2    103   0.04126 *
# res_putamen           1 0.02296    1.210      2    103   0.30232
# kmgroup:res_putamen   1 0.00053    0.027      2    103   0.97292
# Age_yrs:kmgroup       1 0.07703    4.298      2    103   0.01612 *
# kmgroup:res_pall      1 0.08450    4.754      2    103   0.01060 *
# Residuals           104
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#  Response internalizing :
#                      Df  Sum Sq Mean Sq F value    Pr(>F)
# Age_yrs               1  1811.9  1811.9  7.6459  0.006733 **
# kmgroup               1  4013.1  4013.1 16.9345 7.764e-05 ***
# res_pall              1   270.9   270.9  1.1433  0.287425
# res_putamen           1    64.8    64.8  0.2734  0.602142
# kmgroup:res_putamen   1     9.1     9.1  0.0384  0.845107
# Age_yrs:kmgroup       1  1968.6  1968.6  8.3070  0.004799 **
# kmgroup:res_pall      1   408.4   408.4  1.7235  0.192127
# Residuals           104 24645.7   237.0
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Response externalizing :
#                      Df  Sum Sq Mean Sq F value    Pr(>F)
# Age_yrs               1  1963.8  1963.8  8.7250  0.003882 **
# kmgroup               1 10902.9 10902.9 48.4398 3.145e-10 ***
# res_pall              1     6.8     6.8  0.0302  0.862408
# res_putamen           1    13.0    13.0  0.0577  0.810632
# kmgroup:res_putamen   1     2.7     2.7  0.0121  0.912494
# Age_yrs:kmgroup       1  1135.2  1135.2  5.0435  0.026834 *
# kmgroup:res_pall      1     7.2     7.2  0.0320  0.858355
# Residuals           104 23408.4   225.1
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
p <- ggplot(data=complete_data, aes(x=kmgroup, y=res_pall, group=kmgroup, color=kmgroup)) + geom_boxplot()
show(p)
p <- ggplot(data=complete_data, aes(x=kmgroup, y=internalizing, group=kmgroup, color=kmgroup)) + geom_boxplot()
show(p)
p <- ggplot(data=complete_data, aes(x=kmgroup, y=externalizing, group=kmgroup, color=kmgroup)) + geom_boxplot()
show(p)
p <- ggplot(data=complete_data, aes(x=res_pall, y=internalizing, group=kmgroup, color=kmgroup)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)
p <- ggplot(data=complete_data, aes(x=res_pall, y=externalizing, group=kmgroup, color=kmgroup)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
full_model <- manova(cbind(internalizing, externalizing) ~ Age_yrs + Dx_Group + res_putamen + res_pall + Dx_Group*res_putamen + Dx_Group*res_pall, data=complete_data)
summary(full_model)
summary.aov(full_model)
# Out:
#                       Df  Pillai approx F num Df den Df    Pr(>F)
# Age_yrs                1 0.19347   12.473      2    104 1.394e-05 ***
# Dx_Group               1 0.78646  191.514      2    104 < 2.2e-16 ***
# res_putamen            1 0.00672    0.352      2    104  0.704417
# res_pall               1 0.12144    7.188      2    104  0.001192 **
# Dx_Group:res_putamen   1 0.02718    1.453      2    104  0.238600
# Dx_Group:res_pall      1 0.10699    6.230      2    104  0.002784 **
# Residuals            105
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#  Response internalizing :
#                       Df  Sum Sq Mean Sq  F value    Pr(>F)
# Age_yrs                1  1811.9  1811.9  12.7792 0.0005312 ***
# Dx_Group               1 15083.8 15083.8 106.3847 < 2.2e-16 ***
# res_putamen            1    28.5    28.5   0.2009 0.6549492
# res_pall               1   255.0   255.0   1.7982 0.1828297
# Dx_Group:res_putamen   1   293.4   293.4   2.0692 0.1532708
# Dx_Group:res_pall      1   832.6   832.6   5.8722 0.0170928 *
# Residuals            105 14887.5   141.8
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
#  Response externalizing :
#                       Df  Sum Sq Mean Sq  F value    Pr(>F)
# Age_yrs                1  1963.8  1963.8  24.8264 2.481e-06 ***
# Dx_Group               1 26782.5 26782.5 338.5811 < 2.2e-16 ***
# res_putamen            1    49.5    49.5   0.6256   0.43076
# res_pall               1    99.2    99.2   1.2547   0.26521
# Dx_Group:res_putamen   1   230.4   230.4   2.9129   0.09083 .
# Dx_Group:res_pall      1     8.8     8.8   0.1110   0.73971
# Residuals            105  8305.7    79.1
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
p <- ggplot(data=complete_data, aes(x=res_pall, y=internalizing_std, group=Dx_Group, color=Dx_Group)) + geom_point() + geom_smooth(method=lm,se=FALSE)
show(p)

# %% [markdown]
# # Structural Equation Modeling

# %%
library(corrplot)
cor_res<-cor(cbind(complete_data$res_pall,complete_data$res_putamen,complete_data$internalizing,
                   complete_data$externalizing,complete_data$kmgroup), use='complete.obs')
cor_res
corrplot(cor_res, type='upper')
# Out:
#      [,1]        [,2]       [,3]        [,4]       [,5]
# [1,]  1.00000000 0.43890247 -0.01902246 0.12106475 0.1971581
# [2,]  0.43890247 1.00000000  0.04667402 0.05895198 0.1279304
# [3,] -0.01902246 0.04667402  1.00000000 0.87957209 0.3814300
# [4,]  0.12106475 0.05895198  0.87957209 1.00000000 0.5699778
# [5,]  0.19715813 0.12793041  0.38143001 0.56997784 1.0000000
# Plot with title “”

# %%
library(lavaan)

model <- 'internalizing_std ~ c*res_pall
        
          kmgroup ~ a*res_pall
          internalizing_std ~ b*kmgroup
         
          ab:=a*b
          total := c + (a*b)
          '
fit <- sem(model, data=complete_data)
summary(fit)
coef(fit)
# Out:
# lavaan (0.6-1) converged normally after  18 iterations
#
#   Number of observations                           112
#
#   Estimator                                         ML
#   Model Fit Test Statistic                       0.000
#   Degrees of freedom                                 0
#
# Parameter Estimates:
#
#   Information                                 Expected
#   Information saturated (h1) model          Structured
#   Standard Errors                             Standard
#
# Regressions:
#                       Estimate  Std.Err  z-value  P(>|z|)
#   internalizing_std ~
#     res_pall   (c)      -0.154    0.139   -1.106    0.269
#   kmgroup ~
#     res_pall   (a)       0.151    0.071    2.128    0.033
#   internalizing_std ~
#     kmgroup    (b)       0.821    0.181    4.523    0.000
#
# Variances:
#                    Estimate  Std.Err  z-value  P(>|z|)
#    .internlzng_std    0.863    0.115    7.483    0.000
#    .kmgroup           0.234    0.031    7.483    0.000
#
# Defined Parameters:
#                    Estimate  Std.Err  z-value  P(>|z|)
#     ab                0.124    0.065    1.926    0.054
#     total            -0.030    0.149   -0.201    0.840
#                                    c                                    a
#                               -0.154                                0.151
#                                    b internalizing_std~~internalizing_std
#                                0.821                                0.863
#                     kmgroup~~kmgroup
#                                0.234
