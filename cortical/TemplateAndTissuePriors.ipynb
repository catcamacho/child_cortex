# %%
# import all the modules
from nipype.pipeline.engine import Workflow, Node, MapNode
from nipype.interfaces.utility import IdentityInterface, Function
from nipype.interfaces.io import SelectFiles, DataSink, FreeSurferSource
from nipype.interfaces.fsl.preprocess import FAST
from nipype.interfaces.fsl.utils import Reorient2Std
from nipype.interfaces.freesurfer import FSCommand, MRIConvert, Binarize
from nipype.interfaces.ants.registration import RegistrationSynQuick
from pandas import DataFrame, Series, read_csv

# FSL setup- change default file output type
from nipype.interfaces.fsl import FSLCommand
FSLCommand.set_default_output_type('NIFTI_GZ')

#freesurfer setup
fs_dir = '/moochie/Cat/Aggregate_anats/subjects_dir'
FSCommand.set_default_subjects_dir(fs_dir)

# Study specific variables
analysis_home = '/home/camachocm2/Analysis/aggregate_anats'

workflow_dir = analysis_home + '/workflows'
proc_dir = analysis_home + '/proc/subj_data'
group_dir = analysis_home + '/proc/group_data'

#subject_info = read_csv(analysis_home + '/misc/subjs.csv', index_col=0)
#all_subjects = subject_info['fsID'].tolist()
template_subjects_list = analysis_home + '/misc/template_subs.txt'
template_subjects = open(template_subjects_list).read().splitlines()
#template_subjects = [str(template_subjects[0])]

#set up datasink
substitutions = [('_subject_id_','')]
datasink = Node(DataSink(substitutions=substitutions,
                         base_directory = proc_dir),
                name = 'datasink')

# %% [markdown]
# ## 1. Template Brain Creation
# This section creates a template representative of the sample based on a predetermined list.

# %%
##### Set up nodes for file handling #####

template_source = MapNode(FreeSurferSource(subjects_dir = fs_dir), 
                          name = 'template_source', 
                          iterfield = ['subject_id'])
template_source.inputs.subject_id = template_subjects

# %%
######### Template creation functions #########
def make3DTemplate(subject_T1s, num_proc, output_prefix):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    
    from os.path import abspath, split
    from os import getcwd
    from shutil import copyfile
    from glob import glob
    from subprocess import call

    curr_dir = getcwd()

    #copy T1s into current directory
    for T in range(0,len(subject_T1s)):
        [dirname,filename] = split(subject_T1s[T])
        copyfile(subject_T1s[T],curr_dir + '/S' + str(T)+'_'+filename)

    # -c flag is control for local computing (2= use localhost; required for -j flag)
    # -j flag is for number of processors allowed
    call(['antsMultivariateTemplateConstruction2.sh', '–d','3','–o', output_prefix,'–r','1','–c','2','–j', str(num_proc), '*.nii.gz'])
    
    sample_template = abspath(output_prefix + 'template0.nii.gz')
    
    return(sample_template)

# %%
######### Template creation nodes #########

#convert freesurfer brainmask files to .nii
convertT1 = Node(MRIConvert(out_file='T1.nii.gz',
                            out_type='niigz'), 
                 name='convertT1')

#reorient files to standard space
reorientT1 = MapNode(Reorient2Std(),
                     name = 'reorientT1',
                     iterfield = ['in_file'])

#pass files into template function (normalized, pre-skull-stripping)
makeTemplate = Node(Function(input_names=['subject_T1s','num_proc','output_prefix'],
                             output_names=['sample_template'],
                             function=make3DTemplate),
                    name='makeTemplate')
makeTemplate.inputs.num_proc=4 
makeTemplate.inputs.output_prefix='Child_'

# %%
######### Template creation workflow #########
template_flow = Workflow(name = "template_flow")
template_flow.connect([(template_source, convertT1, [('T1','in_file')]),
                       (convertT1, reorientT1, [('out_file', 'in_file')]),
                       (reorientT1, makeTemplate, [('out_file', 'subject_T1s')]),
                       (reorientT1, datasink, [('out_file','proc_T1s')]),
                       (makeTemplate, datasink, [('sample_template', 'sample_template')])
                      ])

template_flow.base_dir = workflow_dir
template_flow.write_graph(graph2use = 'flat')
template_flow.run(plugin='MultiProc',plugin_args={'memory_gb':10})

# %% [markdown]
# ## 2. Tissue Segmentation
# This next section creates the 4 tissue segmentations plus a brainmask for cortical thickness estimation tissue priors:
# 1. CSF
# 2. cortical gray matter
# 3. Subcortical gray matter
# 4. White matter
# 5. Brainstem
# 6. Cerebellum

# %%
## data handling nodes

# subject handling node
infosource = Node(IdentityInterface(fields=['subject_id']), 
                  name='infosource')
infosource.iterables = [('subject_id', template_subjects)]


#pull freesurfer data
tissue_source = Node(FreeSurferSource(subjects_dir = fs_dir),
                     name = 'tissue_source')

# %%
## Tissue labeling functions

def relabel_fast(fast_tissue_list):
    from nipype import config, logging
    from os.path import split
    from os import rename
    config.enable_debug_mode()
    logging.update_logging(config)
    tissue_list = sorted(fast_tissue_list)
    csf = tissue_list[0]
    wm = tissue_list[2]
    [wd, csf_file] = split(csf)
    [wd, wm_file] = split(wm)
    rename(csf, wd + 'csf.nii.gz')
    rename(wm, wd + 'wm.nii.gz')
    wm_csf = [wd + 'csf.nii.gz', wd + 'wm.nii.gz']
    return(wm_csf)

# Create subcortical and cortical gray matter masks <-- custom function. inputs: fs aseg + tissue class files
def aseg_to_tissuemaps(aseg):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nibabel import load, save, Nifti1Image
    from numpy import zeros_like
    from os.path import abspath
    aseg_nifti = load(aseg)
    aseg_data = aseg_nifti.get_data()
    cortical_labels = [3, 42]
    subcortical_labels =[10, 11, 12, 13, 17, 18, 26, 49, 50, 51, 52, 53, 54, 58, 28, 60]
    brainstem_labels = [16]
    cerebellum_labels = [6, 7, 8, 45, 46, 47]

    #creating array of zeroes that replaces 0's with 1's when matches values of subcortical_labels
    cortical_data = zeros_like(aseg_data)
    for x in cortical_labels:
        cortical_data[aseg_data == x] = 1
    cortical_nifti = Nifti1Image(cortical_data, aseg_nifti.affine)
    
    subcort_data = zeros_like(aseg_data) 
    for x in subcortical_labels:
        subcort_data[aseg_data == x] = 1
    subcort_nifti = Nifti1Image(subcort_data, aseg_nifti.affine)
    
    bs_data = zeros_like(aseg_data) 
    for x in brainstem_labels:
        bs_data[aseg_data == x] = 1
    bs_nifti = Nifti1Image(bs_data, aseg_nifti.affine)
    
    cb_data = zeros_like(aseg_data) 
    for x in cerebellum_labels:
        cb_data[aseg_data == x] = 1
    cb_nifti = Nifti1Image(cb_data, aseg_nifti.affine)
    
    save(subcort_nifti, 'subcortical_gm.nii.gz')
    save(cortical_nifti, 'cortical_gm.nii.gz')
    save(bs_nifti, 'brainstem.nii.gz')
    save(cb_nifti, 'cerebellum.nii.gz')
    subcort_file = abspath('subcortical_gm.nii.gz')
    cortical_file = abspath('cortical_gm.nii.gz')
    brainstem_file = abspath('brainstem.nii.gz')
    cerebellum_file = abspath('cerebellum.nii.gz')
    gm_list = [subcort_file, cortical_file, brainstem_file, cerebellum_file]
    return(gm_list)

def combine_seg(file_list_1, file_list_2):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nibabel import load, save, Nifti1Image
    from numpy import zeros_like
    from os.path import abspath

    in_files = file_list_1 + file_list_2

    for tissue in in_files:
        if 'segmentcsf' in tissue:
            csf_file = tissue
            csf_nifti = load(csf_file)
            csf_data = csf_nifti.get_data()
        elif 'subcortical' in tissue:
            subcortical_file = tissue
            sc_nifti = load(subcortical_file)
            sc_data = sc_nifti.get_data()
        elif 'cortical' in tissue:
            cortex_file = tissue
            cort_nifti = load(cortex_file)
            cort_data = cort_nifti.get_data()
        elif 'segmentwm' in tissue:
            wm_file = tissue
            wm_nifti = load(wm_file)
            wm_data = wm_nifti.get_data()
        elif 'brainstem' in tissue:
            brainstem_file = tissue
            bs_nifti = load(brainstem_file)
            bs_data = bs_nifti.get_data()
        elif 'cerebellum' in tissue:
            cerebellum_file = tissue
            cb_nifti = load(cerebellum_file)
            cb_data = cb_nifti.get_data()

    combined_labels_data = zeros_like(csf_data)

    # these are done in a deliberate order, later tissues overwrite previous ones
    combined_labels_data[csf_data>0] = 1
    combined_labels_data[wm_data>0] = 4
    combined_labels_data[bs_data>0] = 5
    combined_labels_data[sc_data>0] = 3
    combined_labels_data[cb_data>0] = 6
    combined_labels_data[cort_data>0] = 2

    combined_labels_nii = Nifti1Image(combined_labels_data, csf_nifti.affine)
    combined_labels_file = save(combined_labels_nii, 'combined_tissues.nii.gz')
    tissue_map = abspath('combined_tissues.nii.gz')
    
    return(tissue_map)

# %%
## tissue labeling nodes

#convert freesurfer brainmask files to .nii
convert_to_nii = Node(MRIConvert(out_file='brain.nii.gz',
                                 out_type='niigz'), 
                      name='convert_to_nii')

#reorient brainmask file to standard
reorient_to_std = Node(Reorient2Std(),
                       name = 'reorient_to_std')

#convert freesurfer brainmask files to .nii
convert_T1 = Node(MRIConvert(out_file='brain.nii.gz',
                             out_type='niigz'),
                  name='convert_T1')

#reorient brainmask file to standard
reorient_T1 = Node(Reorient2Std(),
                   name = 'reorient_T1')

# Reorient aseg to standard
reorient_aseg = Node(Reorient2Std(),
                     name = 'reorient_aseg')

#T1 gets run through segmentation (2) ---> results in segmentation into 3 tissue classes (wm, gm, csf)
segment = Node(FAST(number_classes = 3, 
                    segments=True, 
                    no_bias=True), 
               name = 'segment')

# Convert freesurfer aseg to nii
convert_aseg = Node(MRIConvert(out_file='aseg.nii.gz',
                               out_type='niigz'), 
                    name='convert_aseg')

# Split aseg into to types of gray matter
aseg_to_gm = Node(Function(input_names=['aseg'],
                           output_names=['gm_list'],
                           function=aseg_to_tissuemaps),
                  name='aseg_to_gm')

# Relabel the FAST segmentation 
relabel_fast_seg = Node(Function(input_names=['fast_tissue_list'],
                                 output_names=['wm_csf'],
                                 function=relabel_fast),
                        name='relabel_fast_seg')

#combine tissue segmentation to 1 volume for easier editing of tissue priors
combine_labels = Node(Function(input_names=['file_list_1', 'file_list_2'], 
                               output_names=['tissue_map'], 
                               function=combine_seg),
                      name='combine_labels')

# %%
######### Tissue segmentation workflow #########
segment_flow = Workflow(name = 'segment_flow')
segment_flow.connect([(infosource, tissue_source, [('subject_id','subject_id')]),
                      (tissue_source, convert_to_nii, [('brainmask','in_file')]),
                      (convert_to_nii, reorient_to_std, [('out_file', 'in_file')]),
                      (reorient_to_std, segment, [('out_file', 'in_files')]),
                      (segment, relabel_fast_seg, [('tissue_class_files', 'fast_tissue_list')]),
                      (tissue_source, convert_aseg, [('aseg','in_file')]),
                      (convert_aseg, reorient_aseg, [('out_file', 'in_file')]),
                      (reorient_aseg, aseg_to_gm, [('out_file', 'aseg')]),
                      (aseg_to_gm, combine_labels, [('gm_list','file_list_1')]),
                      (relabel_fast_seg, combine_labels, [('wm_csf','file_list_2')]),
                      (tissue_source, convert_T1, [('T1','in_file')]),
                      (convert_T1, reorient_T1, [('out_file','in_file')]),
                      
                      (reorient_T1, datasink, [('out_file','subject_T1')]),
                      (combine_labels, datasink, [('tissue_map','combined_labels')])
                     ])

segment_flow.base_dir = workflow_dir
segment_flow.write_graph(graph2use = 'flat')
segment_flow.run('MultiProc', plugin_args={'n_procs': 1, 'memory_gb':4})
# Out:
# 180517-14:14:40,113 workflow INFO:
# 	 Generated workflow graph: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/graph.png (graph2use=flat, simple_form=True).
# 180517-14:14:40,164 workflow INFO:
# 	 Workflow segment_flow settings: ['check', 'execution', 'logging', 'monitoring']
# 180517-14:14:40,765 workflow INFO:
# 	 Running in parallel.
# 180517-14:14:40,798 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 40 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:14:41,0 workflow INFO:
# 	 [Node] Setting-up "segment_flow.tissue_source" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/tissue_source".
# 180517-14:14:41,13 workflow INFO:
# 	 [Node] Running "tissue_source" ("nipype.interfaces.io.FreeSurferSource")
# 180517-14:14:41,260 workflow INFO:
# 	 [Node] Finished "segment_flow.tissue_source".
# 180517-14:14:42,799 workflow INFO:
# 	 [Job 0] Completed (segment_flow.tissue_source).
# 180517-14:14:42,810 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 42 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:14:42,974 workflow INFO:
# 	 [Node] Setting-up "segment_flow.convert_to_nii" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_to_nii".
# 180517-14:14:42,991 workflow INFO:
# 	 [Node] Running "convert_to_nii" ("nipype.interfaces.freesurfer.preprocess.MRIConvert"), a CommandLine Interface with command:
# mri_convert --out_type nii --input_volume /moochie/Cat/Aggregate_anats/subjects_dir/2003/mri/brainmask.mgz --output_volume brain.nii.gz
# 180517-14:14:44,809 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 41 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.convert_to_nii
# 180517-14:14:45,174 workflow INFO:
# 	 [Node] Finished "segment_flow.convert_to_nii".
# 180517-14:14:46,804 workflow INFO:
# 	 [Job 1] Completed (segment_flow.convert_to_nii).
# 180517-14:14:46,817 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 42 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:14:46,965 workflow INFO:
# 	 [Node] Setting-up "segment_flow.reorient_to_std" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_to_std".
# 180517-14:14:46,977 workflow INFO:
# 	 [Node] Running "reorient_to_std" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_to_nii/brain.nii.gz /home/camachocm2/Analysis/aggregate_anats/child_cortex/brain_reoriented.nii.gz
# 180517-14:14:47,842 workflow INFO:
# 	 [Node] Finished "segment_flow.reorient_to_std".
# 180517-14:14:48,806 workflow INFO:
# 	 [Job 2] Completed (segment_flow.reorient_to_std).
# 180517-14:14:48,816 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 42 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:14:48,955 workflow INFO:
# 	 [Node] Setting-up "segment_flow.segment" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/segment".
# 180517-14:14:48,965 workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -N -n 3 -g -S 1 /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/segment/brain_reoriented.nii.gz
# 180517-14:14:50,813 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 41 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.segment
# 180517-14:17:55,848 workflow INFO:
# 	 [Node] Finished "segment_flow.segment".
# 180517-14:17:57,15 workflow INFO:
# 	 [Job 3] Completed (segment_flow.segment).
# 180517-14:17:57,25 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 42 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:17:57,141 workflow INFO:
# 	 [Node] Setting-up "segment_flow.relabel_fast_seg" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/relabel_fast_seg".
# 180517-14:17:57,147 workflow INFO:
# 	 [Node] Running "relabel_fast_seg" ("nipype.interfaces.utility.wrappers.Function")
# 180517-14:17:57,154 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/segmentcsf.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/segmentwm.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/relabel_fast_seg/_0xff5fdbbb78af7a1ef8b09d5806202844_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/relabel_fast_seg/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/relabel_fast_seg/_node.pklz
# 180517-14:17:57,158 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/relabel_fast_seg/_report
# 180517-14:17:57,162 workflow DEBUG:
# 	 Removing files:
# 180517-14:17:57,166 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/relabel_fast_seg/result_relabel_fast_seg.pklz
# 180517-14:17:57,170 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/relabel_fast_seg/_report/report.rst"
# 180517-14:17:57,176 workflow DEBUG:
# 	 Aggregate: False
# 180517-14:17:57,184 workflow INFO:
# 	 [Node] Finished "segment_flow.relabel_fast_seg".
# 180517-14:17:59,18 workflow INFO:
# 	 [Job 4] Completed (segment_flow.relabel_fast_seg).
# 180517-14:17:59,28 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 41 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:17:59,161 workflow INFO:
# 	 [Node] Setting-up "segment_flow.convert_aseg" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg".
# 180517-14:17:59,166 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg".
# 180517-14:17:59,170 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg/_report/report.rst"
# 180517-14:17:59,177 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-14:17:59,182 interface DEBUG:
# 	 in_file_/moochie/Cat/Aggregate_anats/subjects_dir/2003/mri/aseg.mgz
# 180517-14:17:59,186 interface DEBUG:
# 	 out_file_aseg.nii.gz
# 180517-14:17:59,189 workflow INFO:
# 	 [Node] Running "convert_aseg" ("nipype.interfaces.freesurfer.preprocess.MRIConvert"), a CommandLine Interface with command:
# mri_convert --out_type nii --input_volume /moochie/Cat/Aggregate_anats/subjects_dir/2003/mri/aseg.mgz --output_volume aseg.nii.gz
# 180517-14:17:59,195 interface DEBUG:
# 	 in_file_/moochie/Cat/Aggregate_anats/subjects_dir/2003/mri/aseg.mgz
# 180517-14:17:59,199 interface DEBUG:
# 	 out_file_aseg.nii.gz
# 180517-14:18:01,24 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 40 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.convert_aseg
# 180517-14:18:02,754 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg/aseg.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg/_0xb54c2348d29311ca09663ade355c1b6d_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg/command.txt;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg/_node.pklz
# 180517-14:18:02,758 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg/_report
# 180517-14:18:02,761 workflow DEBUG:
# 	 Removing files:
# 180517-14:18:02,765 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg/result_convert_aseg.pklz
# 180517-14:18:02,769 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg/_report/report.rst"
# 180517-14:18:02,773 workflow DEBUG:
# 	 Aggregate: False
# 180517-14:18:02,777 workflow INFO:
# 	 [Node] Finished "segment_flow.convert_aseg".
# 180517-14:18:03,21 workflow INFO:
# 	 [Job 5] Completed (segment_flow.convert_aseg).
# 180517-14:18:03,31 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 41 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:03,130 workflow INFO:
# 	 [Node] Setting-up "segment_flow.reorient_aseg" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_aseg".
# 180517-14:18:03,133 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_aseg".
# 180517-14:18:03,136 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_aseg/_report/report.rst"
# 180517-14:18:03,141 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-14:18:03,144 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg/aseg.nii.gz
# 180517-14:18:03,146 interface DEBUG:
# 	 out_file_/home/camachocm2/Analysis/aggregate_anats/child_cortex/aseg_reoriented.nii.gz
# 180517-14:18:03,149 workflow INFO:
# 	 [Node] Running "reorient_aseg" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg/aseg.nii.gz /home/camachocm2/Analysis/aggregate_anats/child_cortex/aseg_reoriented.nii.gz
# 180517-14:18:03,152 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_aseg/aseg.nii.gz
# 180517-14:18:03,154 interface DEBUG:
# 	 out_file_/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_aseg/aseg_reoriented.nii.gz
# 180517-14:18:04,542 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_aseg/aseg_reoriented.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_aseg/_0xdda0340068e2e4ac35299ed5a7c949b3_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_aseg/command.txt;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_aseg/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_aseg/_node.pklz
# 180517-14:18:04,546 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_aseg/_report
# 180517-14:18:04,550 workflow DEBUG:
# 	 Removing files:
# 180517-14:18:04,555 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_aseg/result_reorient_aseg.pklz
# 180517-14:18:04,559 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_aseg/_report/report.rst"
# 180517-14:18:04,563 workflow DEBUG:
# 	 Aggregate: False
# 180517-14:18:04,568 workflow INFO:
# 	 [Node] Finished "segment_flow.reorient_aseg".
# 180517-14:18:05,23 workflow INFO:
# 	 [Job 6] Completed (segment_flow.reorient_aseg).
# 180517-14:18:05,32 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 41 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:05,123 workflow INFO:
# 	 [Node] Setting-up "segment_flow.aseg_to_gm" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/aseg_to_gm".
# 180517-14:18:05,127 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/aseg_to_gm".
# 180517-14:18:05,133 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/aseg_to_gm/_report/report.rst"
# 180517-14:18:05,140 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-14:18:05,143 workflow INFO:
# 	 [Node] Running "aseg_to_gm" ("nipype.interfaces.utility.wrappers.Function")
# 180517-14:18:07,30 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 40 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.aseg_to_gm
# 180517-14:18:12,585 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/aseg_to_gm/subcortical_gm.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/aseg_to_gm/cortical_gm.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/aseg_to_gm/brainstem.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/aseg_to_gm/cerebellum.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/aseg_to_gm/_0x88d42147288b47bd50d59418295d2089_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/aseg_to_gm/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/aseg_to_gm/_node.pklz
# 180517-14:18:12,589 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/aseg_to_gm/_report
# 180517-14:18:12,592 workflow DEBUG:
# 	 Removing files:
# 180517-14:18:12,596 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/aseg_to_gm/result_aseg_to_gm.pklz
# 180517-14:18:12,599 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/aseg_to_gm/_report/report.rst"
# 180517-14:18:12,603 workflow DEBUG:
# 	 Aggregate: False
# 180517-14:18:12,606 workflow INFO:
# 	 [Node] Finished "segment_flow.aseg_to_gm".
# 180517-14:18:13,32 workflow INFO:
# 	 [Job 7] Completed (segment_flow.aseg_to_gm).
# 180517-14:18:13,41 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 41 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:13,134 workflow INFO:
# 	 [Node] Setting-up "segment_flow.combine_labels" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/combine_labels".
# 180517-14:18:13,137 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/combine_labels".
# 180517-14:18:13,141 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/combine_labels/_report/report.rst"
# 180517-14:18:13,147 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-14:18:13,150 workflow INFO:
# 	 [Node] Running "combine_labels" ("nipype.interfaces.utility.wrappers.Function")
# 180517-14:18:15,39 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 40 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.combine_labels
# 180517-14:18:16,50 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/combine_labels/combined_tissues.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/combine_labels/_0x65e85d63c0ef69e79d7896b361ebfb70_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/combine_labels/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/combine_labels/_node.pklz
# 180517-14:18:16,55 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/combine_labels/_report
# 180517-14:18:16,58 workflow DEBUG:
# 	 Removing files:
# 180517-14:18:16,62 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/combine_labels/result_combine_labels.pklz
# 180517-14:18:16,64 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/combine_labels/_report/report.rst"
# 180517-14:18:16,67 workflow DEBUG:
# 	 Aggregate: False
# 180517-14:18:16,70 workflow INFO:
# 	 [Node] Finished "segment_flow.combine_labels".
# 180517-14:18:17,37 workflow INFO:
# 	 [Job 8] Completed (segment_flow.combine_labels).
# 180517-14:18:17,46 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 40 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:17,174 workflow INFO:
# 	 [Node] Setting-up "segment_flow.convert_T1" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_T1".
# 180517-14:18:17,178 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_T1".
# 180517-14:18:17,183 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_T1/_report/report.rst"
# 180517-14:18:17,190 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-14:18:17,196 interface DEBUG:
# 	 in_file_/moochie/Cat/Aggregate_anats/subjects_dir/2003/mri/T1.mgz
# 180517-14:18:17,199 interface DEBUG:
# 	 out_file_brain.nii.gz
# 180517-14:18:17,202 workflow INFO:
# 	 [Node] Running "convert_T1" ("nipype.interfaces.freesurfer.preprocess.MRIConvert"), a CommandLine Interface with command:
# mri_convert --out_type nii --input_volume /moochie/Cat/Aggregate_anats/subjects_dir/2003/mri/T1.mgz --output_volume brain.nii.gz
# 180517-14:18:17,210 interface DEBUG:
# 	 in_file_/moochie/Cat/Aggregate_anats/subjects_dir/2003/mri/T1.mgz
# 180517-14:18:17,214 interface DEBUG:
# 	 out_file_brain.nii.gz
# 180517-14:18:19,44 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 39 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.convert_T1
# 180517-14:18:20,166 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_T1/brain.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_T1/_0x21245731b96100ce807f61841bbf9f6f_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_T1/command.txt;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_T1/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_T1/_node.pklz
# 180517-14:18:20,169 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_T1/_report
# 180517-14:18:20,172 workflow DEBUG:
# 	 Removing files:
# 180517-14:18:20,175 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_T1/result_convert_T1.pklz
# 180517-14:18:20,178 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_T1/_report/report.rst"
# 180517-14:18:20,182 workflow DEBUG:
# 	 Aggregate: False
# 180517-14:18:20,186 workflow INFO:
# 	 [Node] Finished "segment_flow.convert_T1".
# 180517-14:18:21,47 workflow INFO:
# 	 [Job 9] Completed (segment_flow.convert_T1).
# 180517-14:18:21,58 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 40 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:21,181 workflow INFO:
# 	 [Node] Setting-up "segment_flow.reorient_T1" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/reorient_T1".
# 180517-14:18:21,192 workflow INFO:
# 	 [Node] Running "reorient_T1" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/convert_T1/brain.nii.gz /home/camachocm2/Analysis/aggregate_anats/child_cortex/brain_reoriented.nii.gz
# 180517-14:18:22,46 workflow INFO:
# 	 [Node] Finished "segment_flow.reorient_T1".
# 180517-14:18:23,43 workflow INFO:
# 	 [Job 10] Completed (segment_flow.reorient_T1).
# 180517-14:18:23,53 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 40 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:23,150 workflow INFO:
# 	 [Node] Setting-up "segment_flow.datasink" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_2003/datasink".
# 180517-14:18:23,161 workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 180517-14:18:23,165 interface INFO:
# 	 sub: /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/_subject_id_2003/brain_reoriented.nii.gz -> /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/2003/brain_reoriented.nii.gz
# 180517-14:18:23,169 interface INFO:
# 	 sub: /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/_subject_id_2003/combined_tissues.nii.gz -> /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/2003/combined_tissues.nii.gz
# 180517-14:18:23,174 workflow INFO:
# 	 [Node] Finished "segment_flow.datasink".
# 180517-14:18:25,45 workflow INFO:
# 	 [Job 11] Completed (segment_flow.datasink).
# 180517-14:18:25,56 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 39 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:25,154 workflow INFO:
# 	 [Node] Setting-up "segment_flow.tissue_source" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/tissue_source".
# 180517-14:18:25,159 workflow INFO:
# 	 [Node] Running "tissue_source" ("nipype.interfaces.io.FreeSurferSource")
# 180517-14:18:25,347 workflow INFO:
# 	 [Node] Finished "segment_flow.tissue_source".
# 180517-14:18:27,47 workflow INFO:
# 	 [Job 12] Completed (segment_flow.tissue_source).
# 180517-14:18:27,56 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 41 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:27,168 workflow INFO:
# 	 [Node] Setting-up "segment_flow.convert_aseg" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_aseg".
# 180517-14:18:27,180 workflow INFO:
# 	 [Node] Running "convert_aseg" ("nipype.interfaces.freesurfer.preprocess.MRIConvert"), a CommandLine Interface with command:
# mri_convert --out_type nii --input_volume /moochie/Cat/Aggregate_anats/subjects_dir/D1018/mri/aseg.mgz --output_volume aseg.nii.gz
# 180517-14:18:29,55 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 40 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.convert_aseg
# 180517-14:18:29,524 workflow INFO:
# 	 [Node] Finished "segment_flow.convert_aseg".
# 180517-14:18:31,51 workflow INFO:
# 	 [Job 13] Completed (segment_flow.convert_aseg).
# 180517-14:18:31,60 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 41 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:31,152 workflow INFO:
# 	 [Node] Setting-up "segment_flow.reorient_aseg" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_aseg".
# 180517-14:18:31,161 workflow INFO:
# 	 [Node] Running "reorient_aseg" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_aseg/aseg.nii.gz /home/camachocm2/Analysis/aggregate_anats/child_cortex/aseg_reoriented.nii.gz
# 180517-14:18:32,415 workflow INFO:
# 	 [Node] Finished "segment_flow.reorient_aseg".
# 180517-14:18:33,54 workflow INFO:
# 	 [Job 14] Completed (segment_flow.reorient_aseg).
# 180517-14:18:33,65 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 41 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:33,161 workflow INFO:
# 	 [Node] Setting-up "segment_flow.aseg_to_gm" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/aseg_to_gm".
# 180517-14:18:33,168 workflow INFO:
# 	 [Node] Running "aseg_to_gm" ("nipype.interfaces.utility.wrappers.Function")
# 180517-14:18:35,64 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 40 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.aseg_to_gm
# 180517-14:18:40,594 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/aseg_to_gm/subcortical_gm.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/aseg_to_gm/cortical_gm.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/aseg_to_gm/brainstem.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/aseg_to_gm/cerebellum.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/aseg_to_gm/_0x9df4f071afe8f8c5d41134e2982bfa1a_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/aseg_to_gm/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/aseg_to_gm/_node.pklz
# 180517-14:18:40,598 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/aseg_to_gm/_report
# 180517-14:18:40,601 workflow DEBUG:
# 	 Removing files:
# 180517-14:18:40,605 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/aseg_to_gm/result_aseg_to_gm.pklz
# 180517-14:18:40,608 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/aseg_to_gm/_report/report.rst"
# 180517-14:18:40,611 workflow DEBUG:
# 	 Aggregate: False
# 180517-14:18:40,615 workflow INFO:
# 	 [Node] Finished "segment_flow.aseg_to_gm".
# 180517-14:18:41,63 workflow INFO:
# 	 [Job 15] Completed (segment_flow.aseg_to_gm).
# 180517-14:18:41,72 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 40 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:41,192 workflow INFO:
# 	 [Node] Setting-up "segment_flow.convert_T1" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1".
# 180517-14:18:41,196 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1".
# 180517-14:18:41,200 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1/_report/report.rst"
# 180517-14:18:41,207 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-14:18:41,216 interface DEBUG:
# 	 in_file_/moochie/Cat/Aggregate_anats/subjects_dir/D1018/mri/T1.mgz
# 180517-14:18:41,220 interface DEBUG:
# 	 out_file_brain.nii.gz
# 180517-14:18:41,224 workflow INFO:
# 	 [Node] Running "convert_T1" ("nipype.interfaces.freesurfer.preprocess.MRIConvert"), a CommandLine Interface with command:
# mri_convert --out_type nii --input_volume /moochie/Cat/Aggregate_anats/subjects_dir/D1018/mri/T1.mgz --output_volume brain.nii.gz
# 180517-14:18:41,231 interface DEBUG:
# 	 in_file_/moochie/Cat/Aggregate_anats/subjects_dir/D1018/mri/T1.mgz
# 180517-14:18:41,235 interface DEBUG:
# 	 out_file_brain.nii.gz
# 180517-14:18:43,71 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 39 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.convert_T1
# 180517-14:18:43,74 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1/brain.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1/_0x189e0ed795aed77eb7ec95f12c0e7899_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1/command.txt;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1/_node.pklz
# 180517-14:18:43,78 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1/_report
# 180517-14:18:43,82 workflow DEBUG:
# 	 Removing files:
# 180517-14:18:43,86 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1/result_convert_T1.pklz
# 180517-14:18:43,90 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1/_report/report.rst"
# 180517-14:18:43,94 workflow DEBUG:
# 	 Aggregate: False
# 180517-14:18:43,98 workflow INFO:
# 	 [Node] Finished "segment_flow.convert_T1".
# 180517-14:18:45,67 workflow INFO:
# 	 [Job 16] Completed (segment_flow.convert_T1).
# 180517-14:18:45,76 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 40 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:45,198 workflow INFO:
# 	 [Node] Setting-up "segment_flow.reorient_T1" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1".
# 180517-14:18:45,202 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1".
# 180517-14:18:45,207 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1/_report/report.rst"
# 180517-14:18:45,213 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-14:18:45,217 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1/brain.nii.gz
# 180517-14:18:45,220 interface DEBUG:
# 	 out_file_/home/camachocm2/Analysis/aggregate_anats/child_cortex/brain_reoriented.nii.gz
# 180517-14:18:45,223 workflow INFO:
# 	 [Node] Running "reorient_T1" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1/brain.nii.gz /home/camachocm2/Analysis/aggregate_anats/child_cortex/brain_reoriented.nii.gz
# 180517-14:18:45,228 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_T1/brain.nii.gz
# 180517-14:18:45,231 interface DEBUG:
# 	 out_file_/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1/brain_reoriented.nii.gz
# 180517-14:18:46,42 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1/brain_reoriented.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1/_0xe361102eb4967e635bc8b0caf398bba8_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1/command.txt;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1/_node.pklz
# 180517-14:18:46,45 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1/_report
# 180517-14:18:46,47 workflow DEBUG:
# 	 Removing files:
# 180517-14:18:46,50 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1/result_reorient_T1.pklz
# 180517-14:18:46,52 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1/_report/report.rst"
# 180517-14:18:46,56 workflow DEBUG:
# 	 Aggregate: False
# 180517-14:18:46,58 workflow INFO:
# 	 [Node] Finished "segment_flow.reorient_T1".
# 180517-14:18:47,70 workflow INFO:
# 	 [Job 17] Completed (segment_flow.reorient_T1).
# 180517-14:18:47,79 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 39 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:47,207 workflow INFO:
# 	 [Node] Setting-up "segment_flow.convert_to_nii" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii".
# 180517-14:18:47,211 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii".
# 180517-14:18:47,216 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii/_report/report.rst"
# 180517-14:18:47,223 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-14:18:47,228 interface DEBUG:
# 	 in_file_/moochie/Cat/Aggregate_anats/subjects_dir/D1018/mri/brainmask.mgz
# 180517-14:18:47,232 interface DEBUG:
# 	 out_file_brain.nii.gz
# 180517-14:18:47,236 workflow INFO:
# 	 [Node] Running "convert_to_nii" ("nipype.interfaces.freesurfer.preprocess.MRIConvert"), a CommandLine Interface with command:
# mri_convert --out_type nii --input_volume /moochie/Cat/Aggregate_anats/subjects_dir/D1018/mri/brainmask.mgz --output_volume brain.nii.gz
# 180517-14:18:47,241 interface DEBUG:
# 	 in_file_/moochie/Cat/Aggregate_anats/subjects_dir/D1018/mri/brainmask.mgz
# 180517-14:18:47,244 interface DEBUG:
# 	 out_file_brain.nii.gz
# 180517-14:18:49,78 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 38 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.convert_to_nii
# 180517-14:18:49,683 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii/brain.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii/_0xad202c275b74bf5138735dee06f06a10_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii/command.txt;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii/_node.pklz
# 180517-14:18:49,686 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii/_report
# 180517-14:18:49,689 workflow DEBUG:
# 	 Removing files:
# 180517-14:18:49,693 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii/result_convert_to_nii.pklz
# 180517-14:18:49,696 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii/_report/report.rst"
# 180517-14:18:49,700 workflow DEBUG:
# 	 Aggregate: False
# 180517-14:18:49,704 workflow INFO:
# 	 [Node] Finished "segment_flow.convert_to_nii".
# 180517-14:18:51,75 workflow INFO:
# 	 [Job 18] Completed (segment_flow.convert_to_nii).
# 180517-14:18:51,85 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 39 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:51,202 workflow INFO:
# 	 [Node] Setting-up "segment_flow.reorient_to_std" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_to_std".
# 180517-14:18:51,205 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_to_std".
# 180517-14:18:51,210 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_to_std/_report/report.rst"
# 180517-14:18:51,216 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-14:18:51,220 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii/brain.nii.gz
# 180517-14:18:51,223 interface DEBUG:
# 	 out_file_/home/camachocm2/Analysis/aggregate_anats/child_cortex/brain_reoriented.nii.gz
# 180517-14:18:51,226 workflow INFO:
# 	 [Node] Running "reorient_to_std" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii/brain.nii.gz /home/camachocm2/Analysis/aggregate_anats/child_cortex/brain_reoriented.nii.gz
# 180517-14:18:51,230 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/convert_to_nii/brain.nii.gz
# 180517-14:18:51,233 interface DEBUG:
# 	 out_file_/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_to_std/brain_reoriented.nii.gz
# 180517-14:18:51,992 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_to_std/brain_reoriented.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_to_std/_0x2c6a8fbb5d83103498d85bd6a726afbf_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_to_std/command.txt;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_to_std/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_to_std/_node.pklz
# 180517-14:18:51,996 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_to_std/_report
# 180517-14:18:52,0 workflow DEBUG:
# 	 Removing files:
# 180517-14:18:52,4 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_to_std/result_reorient_to_std.pklz
# 180517-14:18:52,9 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_to_std/_report/report.rst"
# 180517-14:18:52,13 workflow DEBUG:
# 	 Aggregate: False
# 180517-14:18:52,17 workflow INFO:
# 	 [Node] Finished "segment_flow.reorient_to_std".
# 180517-14:18:53,83 workflow INFO:
# 	 [Job 19] Completed (segment_flow.reorient_to_std).
# 180517-14:18:53,95 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 39 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:18:53,251 workflow INFO:
# 	 [Node] Setting-up "segment_flow.segment" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/segment".
# 180517-14:18:53,265 workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -N -n 3 -g -S 1 /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/segment/brain_reoriented.nii.gz
# 180517-14:18:55,85 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 38 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.segment
# 180517-14:22:00,505 workflow INFO:
# 	 [Node] Finished "segment_flow.segment".
# 180517-14:22:01,286 workflow INFO:
# 	 [Job 20] Completed (segment_flow.segment).
# 180517-14:22:01,299 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 39 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:22:01,433 workflow INFO:
# 	 [Node] Setting-up "segment_flow.relabel_fast_seg" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/relabel_fast_seg".
# 180517-14:22:01,442 workflow INFO:
# 	 [Node] Running "relabel_fast_seg" ("nipype.interfaces.utility.wrappers.Function")
# 180517-14:22:01,450 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/segmentcsf.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/segmentwm.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/relabel_fast_seg/_0x6072c9fd01dded48f77e2d151afb1724_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/relabel_fast_seg/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/relabel_fast_seg/_node.pklz
# 180517-14:22:01,453 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/relabel_fast_seg/_report
# 180517-14:22:01,456 workflow DEBUG:
# 	 Removing files:
# 180517-14:22:01,460 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/relabel_fast_seg/result_relabel_fast_seg.pklz
# 180517-14:22:01,465 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/relabel_fast_seg/_report/report.rst"
# 180517-14:22:01,471 workflow DEBUG:
# 	 Aggregate: False
# 180517-14:22:01,477 workflow INFO:
# 	 [Node] Finished "segment_flow.relabel_fast_seg".
# 180517-14:22:03,289 workflow INFO:
# 	 [Job 21] Completed (segment_flow.relabel_fast_seg).
# 180517-14:22:03,301 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 39 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:22:03,435 workflow INFO:
# 	 [Node] Setting-up "segment_flow.combine_labels" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/combine_labels".
# 180517-14:22:03,440 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/combine_labels".
# 180517-14:22:03,445 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/combine_labels/_report/report.rst"
# 180517-14:22:03,452 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-14:22:03,456 workflow INFO:
# 	 [Node] Running "combine_labels" ("nipype.interfaces.utility.wrappers.Function")
# 180517-14:22:05,298 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 38 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.combine_labels
# 180517-14:22:07,938 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/combine_labels/combined_tissues.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/combine_labels/_0x777994e8510d54234589636b7e9c8fa4_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/combine_labels/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/combine_labels/_node.pklz
# 180517-14:22:07,943 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/combine_labels/_report
# 180517-14:22:07,946 workflow DEBUG:
# 	 Removing files:
# 180517-14:22:07,951 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/combine_labels/result_combine_labels.pklz
# 180517-14:22:07,954 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/combine_labels/_report/report.rst"
# 180517-14:22:07,957 workflow DEBUG:
# 	 Aggregate: False
# 180517-14:22:07,961 workflow INFO:
# 	 [Node] Finished "segment_flow.combine_labels".
# 180517-14:22:09,294 workflow INFO:
# 	 [Job 22] Completed (segment_flow.combine_labels).
# 180517-14:22:09,306 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 39 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-14:22:09,461 workflow INFO:
# 	 [Node] Setting-up "segment_flow.datasink" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/datasink".
# 180517-14:22:09,467 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/datasink".
# 180517-14:22:09,474 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/datasink/_report/report.rst"
# 180517-14:22:09,486 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-14:22:09,492 workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 180517-14:22:09,499 interface DEBUG:
# 	 key: subject_T1 files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1/brain_reoriented.nii.gz
# 180517-14:22:09,504 interface DEBUG:
# 	 sub.str: /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/_subject_id_D1018/brain_reoriented.nii.gz -> /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/D1018/brain_reoriented.nii.gz using '_subject_id_' -> ''
# 180517-14:22:09,508 interface INFO:
# 	 sub: /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/_subject_id_D1018/brain_reoriented.nii.gz -> /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/D1018/brain_reoriented.nii.gz
# 180517-14:22:09,513 interface DEBUG:
# 	 copyfile: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/reorient_T1/brain_reoriented.nii.gz /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/D1018/brain_reoriented.nii.gz
# 180517-14:22:09,518 interface DEBUG:
# 	 key: combined_labels files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/combine_labels/combined_tissues.nii.gz
# 180517-14:22:09,523 interface DEBUG:
# 	 sub.str: /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/_subject_id_D1018/combined_tissues.nii.gz -> /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/D1018/combined_tissues.nii.gz using '_subject_id_' -> ''
# 180517-14:22:09,527 interface INFO:
# 	 sub: /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/_subject_id_D1018/combined_tissues.nii.gz -> /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/D1018/combined_tissues.nii.gz
# 180517-14:22:09,532 interface DEBUG:
# 	 copyfile: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/combine_labels/combined_tissues.nii.gz /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/D1018/combined_tissues.nii.gz
# 180517-14:22:09,541 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/D1018/brain_reoriented.nii.gz;/home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/D1018/combined_tissues.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/datasink/_0xa3487aaa4ab8e823bfc0833c294fa2d1_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/datasink/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_D1018/datasink/_node.pklz
# 180517-14:22:09,546 workflow DEBUG:
# ...
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-16:37:28,222 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/convert_to_nii/brain.nii.gz
# 180517-16:37:28,227 interface DEBUG:
# 	 out_file_/home/camachocm2/Analysis/aggregate_anats/child_cortex/brain_reoriented.nii.gz
# 180517-16:37:28,232 workflow INFO:
# 	 [Node] Running "reorient_to_std" ("nipype.interfaces.fsl.utils.Reorient2Std"), a CommandLine Interface with command:
# fslreorient2std /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/convert_to_nii/brain.nii.gz /home/camachocm2/Analysis/aggregate_anats/child_cortex/brain_reoriented.nii.gz
# 180517-16:37:28,238 interface DEBUG:
# 	 in_file_/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/convert_to_nii/brain.nii.gz
# 180517-16:37:28,243 interface DEBUG:
# 	 out_file_/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/reorient_to_std/brain_reoriented.nii.gz
# 180517-16:37:29,50 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/reorient_to_std/brain_reoriented.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/reorient_to_std/_0xc498983fce44615536ec87ff3cae84de_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/reorient_to_std/command.txt;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/reorient_to_std/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/reorient_to_std/_node.pklz
# 180517-16:37:29,54 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/reorient_to_std/_report
# 180517-16:37:29,56 workflow DEBUG:
# 	 Removing files:
# 180517-16:37:29,60 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/reorient_to_std/result_reorient_to_std.pklz
# 180517-16:37:29,63 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/reorient_to_std/_report/report.rst"
# 180517-16:37:29,67 workflow DEBUG:
# 	 Aggregate: False
# 180517-16:37:29,70 workflow INFO:
# 	 [Node] Finished "segment_flow.reorient_to_std".
# 180517-16:37:30,13 workflow INFO:
# 	 [Job 475] Completed (segment_flow.reorient_to_std).
# 180517-16:37:30,24 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-16:37:30,209 workflow INFO:
# 	 [Node] Setting-up "segment_flow.segment" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment".
# 180517-16:37:30,213 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment".
# 180517-16:37:30,218 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/_report/report.rst"
# 180517-16:37:30,224 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-16:37:30,230 interface DEBUG:
# 	 in_files_['/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/brain_reoriented.nii.gz']
# 180517-16:37:30,233 interface DEBUG:
# 	 no_bias_True
# 180517-16:37:30,236 interface DEBUG:
# 	 number_classes_3
# 180517-16:37:30,239 interface DEBUG:
# 	 segments_True
# 180517-16:37:30,242 workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.fsl.preprocess.FAST"), a CommandLine Interface with command:
# fast -N -n 3 -g -S 1 /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/brain_reoriented.nii.gz
# 180517-16:37:30,247 interface DEBUG:
# 	 in_files_['/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/brain_reoriented.nii.gz']
# 180517-16:37:30,250 interface DEBUG:
# 	 no_bias_True
# 180517-16:37:30,253 interface DEBUG:
# 	 number_classes_3
# 180517-16:37:30,256 interface DEBUG:
# 	 segments_True
# 180517-16:37:32,21 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.segment
# 180517-16:40:41,634 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/brain_reoriented_seg_0.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/brain_reoriented_seg_1.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/brain_reoriented_seg_2.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/_0xa62bc4fac3882a41277e6dc30b1d4201_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/command.txt;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/_node.pklz
# 180517-16:40:41,637 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/_report
# 180517-16:40:41,640 workflow DEBUG:
# 	 Removing files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/brain_reoriented.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/brain_reoriented_seg.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/brain_reoriented_pveseg.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/brain_reoriented_pve_0.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/brain_reoriented_mixeltype.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/brain_reoriented_pve_1.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/brain_reoriented_pve_2.nii.gz
# 180517-16:40:41,644 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/result_segment.pklz
# 180517-16:40:41,648 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segment/_report/report.rst"
# 180517-16:40:41,651 workflow DEBUG:
# 	 Aggregate: False
# 180517-16:40:41,654 workflow INFO:
# 	 [Node] Finished "segment_flow.segment".
# 180517-16:40:42,212 workflow INFO:
# 	 [Job 476] Completed (segment_flow.segment).
# 180517-16:40:42,223 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-16:40:42,427 workflow INFO:
# 	 [Node] Setting-up "segment_flow.relabel_fast_seg" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/relabel_fast_seg".
# 180517-16:40:42,431 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/relabel_fast_seg".
# 180517-16:40:42,435 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/relabel_fast_seg/_report/report.rst"
# 180517-16:40:42,440 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-16:40:42,443 workflow INFO:
# 	 [Node] Running "relabel_fast_seg" ("nipype.interfaces.utility.wrappers.Function")
# 180517-16:40:42,449 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segmentcsf.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/segmentwm.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/relabel_fast_seg/_0xc3bc821694aec87e2975b07eee0b3fbc_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/relabel_fast_seg/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/relabel_fast_seg/_node.pklz
# 180517-16:40:42,452 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/relabel_fast_seg/_report
# 180517-16:40:42,454 workflow DEBUG:
# 	 Removing files:
# 180517-16:40:42,458 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/relabel_fast_seg/result_relabel_fast_seg.pklz
# 180517-16:40:42,462 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/relabel_fast_seg/_report/report.rst"
# 180517-16:40:42,467 workflow DEBUG:
# 	 Aggregate: False
# 180517-16:40:42,472 workflow INFO:
# 	 [Node] Finished "segment_flow.relabel_fast_seg".
# 180517-16:40:44,215 workflow INFO:
# 	 [Job 477] Completed (segment_flow.relabel_fast_seg).
# 180517-16:40:44,225 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-16:40:44,428 workflow INFO:
# 	 [Node] Setting-up "segment_flow.combine_labels" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/combine_labels".
# 180517-16:40:44,432 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/combine_labels".
# 180517-16:40:44,436 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/combine_labels/_report/report.rst"
# 180517-16:40:44,441 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-16:40:44,445 workflow INFO:
# 	 [Node] Running "combine_labels" ("nipype.interfaces.utility.wrappers.Function")
# 180517-16:40:46,221 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 3.80/4.00, Free processors: 0/1.
#                      Currently running:
#                        * segment_flow.combine_labels
# 180517-16:40:47,944 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/combine_labels/combined_tissues.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/combine_labels/_0x302136fa5645a02a7298e58ce0f8bf90_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/combine_labels/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/combine_labels/_node.pklz
# 180517-16:40:47,948 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/combine_labels/_report
# 180517-16:40:47,950 workflow DEBUG:
# 	 Removing files:
# 180517-16:40:47,954 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/combine_labels/result_combine_labels.pklz
# 180517-16:40:47,957 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/combine_labels/_report/report.rst"
# 180517-16:40:47,960 workflow DEBUG:
# 	 Aggregate: False
# 180517-16:40:47,963 workflow INFO:
# 	 [Node] Finished "segment_flow.combine_labels".
# 180517-16:40:48,218 workflow INFO:
# 	 [Job 478] Completed (segment_flow.combine_labels).
# 180517-16:40:48,227 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.
# 180517-16:40:48,443 workflow INFO:
# 	 [Node] Setting-up "segment_flow.datasink" in "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/datasink".
# 180517-16:40:48,448 workflow DEBUG:
# 	 [Node] Directory not found "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/datasink".
# 180517-16:40:48,452 workflow DEBUG:
# 	 [Node] Writing pre-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/datasink/_report/report.rst"
# 180517-16:40:48,459 workflow DEBUG:
# 	 copying files to wd [execute=True, linksonly=False]
# 180517-16:40:48,463 workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 180517-16:40:48,467 interface DEBUG:
# 	 key: combined_labels files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/combine_labels/combined_tissues.nii.gz
# 180517-16:40:48,470 interface DEBUG:
# 	 sub.str: /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/_subject_id_1006/combined_tissues.nii.gz -> /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/1006/combined_tissues.nii.gz using '_subject_id_' -> ''
# 180517-16:40:48,474 interface INFO:
# 	 sub: /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/_subject_id_1006/combined_tissues.nii.gz -> /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/1006/combined_tissues.nii.gz
# 180517-16:40:48,478 interface DEBUG:
# 	 copyfile: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/combine_labels/combined_tissues.nii.gz /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/1006/combined_tissues.nii.gz
# 180517-16:40:48,484 interface DEBUG:
# 	 key: subject_T1 files: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/reorient_T1/brain_reoriented.nii.gz
# 180517-16:40:48,488 interface DEBUG:
# 	 sub.str: /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/_subject_id_1006/brain_reoriented.nii.gz -> /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/1006/brain_reoriented.nii.gz using '_subject_id_' -> ''
# 180517-16:40:48,492 interface INFO:
# 	 sub: /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/_subject_id_1006/brain_reoriented.nii.gz -> /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/1006/brain_reoriented.nii.gz
# 180517-16:40:48,496 interface DEBUG:
# 	 copyfile: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/reorient_T1/brain_reoriented.nii.gz /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/1006/brain_reoriented.nii.gz
# 180517-16:40:48,500 workflow DEBUG:
# 	 Needed files: /home/camachocm2/Analysis/aggregate_anats/proc/subj_data/combined_labels/1006/combined_tissues.nii.gz;/home/camachocm2/Analysis/aggregate_anats/proc/subj_data/subject_T1/1006/brain_reoriented.nii.gz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/datasink/_0x3db096a4abc8efe7a3a52db8d31e0bc9_unfinished.json;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/datasink/_inputs.pklz;/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/datasink/_node.pklz
# 180517-16:40:48,503 workflow DEBUG:
# 	 Needed dirs: /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/datasink/_report
# 180517-16:40:48,506 workflow DEBUG:
# 	 Removing files:
# 180517-16:40:48,509 workflow DEBUG:
# 	 saved results in /home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/datasink/result_datasink.pklz
# 180517-16:40:48,512 workflow DEBUG:
# 	 [Node] Writing post-exec report to "/home/camachocm2/Analysis/aggregate_anats/workflows/segment_flow/_subject_id_1006/datasink/_report/report.rst"
# 180517-16:40:48,516 workflow DEBUG:
# 	 Aggregate: False
# 180517-16:40:48,519 workflow INFO:
# 	 [Node] Finished "segment_flow.datasink".
# 180517-16:40:50,223 workflow INFO:
# 	 [Job 479] Completed (segment_flow.datasink).
# 180517-16:40:50,234 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 4.00/4.00, Free processors: 1/1.

# %% [markdown]
# ## 3. Tissue Priors
# This section creates the tissue priors (after manual editing the ouputs from the previous step)

# %%
### Data handling nodes
template= proc_dir + '/template/lcbd_template0.nii.gz'
file_template = {'tissue_map': proc_dir + '/combined_labels/{subject_id}/combined_tissues.nii.gz'}
template_files = Node(SelectFiles(file_template), name='template_files')

# %%
def split_tissue_labels(combined_labels):
    from nipype import config, logging
    config.enable_debug_mode()
    logging.update_logging(config)
    from nibabel import load, save, Nifti1Image
    from numpy import zeros_like
    from os.path import abspath
    
    labeled_nifti = load(combined_labels)
    labeled_data = labeled_nifti.get_data()
    
    for seg in range(1,6):
        temp = zeros_like(labeled_data)
        
    
    
    return(segment1,segment2,segment3,segment4,segment5,segment6)

# %%
### Tissue priors nodes

# register to template
reg_to_template = Node(RegistrationSynQuick(fixed_image=template), 
                       name = 'reg_to_template')

# apply the transform to the tissue maps


# average the tissue maps

# %%
tissuepriors_flow = Workflow(name = 'tissuepriors_flow')
tissuepriors_flow.connect([(infosource, tissue_source, [('subject_id','subject_id')]),
                           (tissue_source, convert_to_nii, [('T1','in_file')]),
                           (convert_to_nii, reorient_to_std, [('out_file','in_file')]),
                           (reorient_to_std, reg_to_template, [('')])
                          ])

tissuepriors_flow.base_dir = workflow_dir
tissuepriors_flow.write_graph(graph2use = 'flat')
tissuepriors_flow.run('MultiProc', plugin_args={'n_procs': 4, 'memory_gb':10})

# %% [markdown]
# ## 4. Calculate Cortical Thickness
# This section now takes all these items and calculates cortical thickness per subject. Last step before group analysis!
