# %%
library(psych)

setwd('/home/camachocm2/Analysis/aggregate_anats/results/')
cbq_data <- read.csv('/home/camachocm2/Analysis/aggregate_anats/cleaned_data/subject_data_20190311.csv')
cbq_data
# Out:
#     freesurferID activity_level anger_frustration attention_focusing discomfort
# 1   101          4.142857       4.500000          5.166667           3.833333
# 2   102          4.428571       4.000000          5.166667           4.000000
# 3   105          4.714286       5.833333          3.833333           3.166667
# 4   107          4.285714       1.500000          5.000000           2.333333
# 5   109          3.857143       1.500000          6.000000           4.500000
# 6   110          4.714286       5.166667          6.166667           3.833333
# 7   111          4.714286       4.666667          4.166667           4.333333
# 8   112          4.142857       3.500000          4.666667           3.833333
# 9   113          3.571429       3.000000          6.833333           2.333333
# 10  115          4.714286       3.500000          6.500000           3.666667
# 11  116          4.428571       1.833333          5.833333           3.666667
# ...

# %%
features<-cbq_data[,2:14]
cor.plot(features)
# Out:
# Plot with title “Correlation plot”

# %%
model <- fa(features,2,rotate='varimax')
model
# Out:
# Factor Analysis using method =  minres
# Call: fa(r = features, nfactors = 2, rotate = "varimax")
# Standardized loadings (pattern matrix) based upon correlation matrix
#                           MR1  MR2    h2   u2 com
# activity_level           0.65 0.16 0.445 0.56 1.1
# anger_frustration        0.73 0.29 0.613 0.39 1.3
# attention_focusing      -0.64 0.15 0.436 0.56 1.1
# discomfort               0.34 0.49 0.354 0.65 1.8
# soothability            -0.70 0.04 0.495 0.50 1.0
# fear                     0.09 0.41 0.173 0.83 1.1
# high_intensity_pleasure  0.43 0.31 0.276 0.72 1.8
# impulsivity              0.61 0.14 0.392 0.61 1.1
# inhibitory_control      -0.77 0.18 0.632 0.37 1.1
# low_intensity_pleasure  -0.16 0.68 0.489 0.51 1.1
# perceptual_sensitivity  -0.18 0.65 0.453 0.55 1.2
# sadness                  0.47 0.45 0.418 0.58 2.0
# shyness                 -0.10 0.06 0.015 0.99 1.6
#
#                        MR1  MR2
# SS loadings           3.43 1.77
# ...

# %%
model <- fa(features,3,rotate='varimax')
model
# Out:
# Factor Analysis using method =  minres
# Call: fa(r = features, nfactors = 3, rotate = "varimax")
# Standardized loadings (pattern matrix) based upon correlation matrix
#                           MR1  MR2   MR3   h2   u2 com
# activity_level           0.42 0.10  0.65 0.61 0.39 1.7
# anger_frustration        0.84 0.26  0.07 0.78 0.22 1.2
# attention_focusing      -0.55 0.19 -0.29 0.42 0.58 1.8
# discomfort               0.45 0.49 -0.04 0.44 0.56 2.0
# soothability            -0.75 0.09 -0.10 0.59 0.41 1.1
# fear                     0.15 0.41 -0.05 0.19 0.81 1.3
# high_intensity_pleasure  0.26 0.27  0.46 0.35 0.65 2.2
# impulsivity              0.35 0.08  0.73 0.66 0.34 1.5
# inhibitory_control      -0.66 0.23 -0.35 0.61 0.39 1.8
# low_intensity_pleasure  -0.22 0.70  0.15 0.57 0.43 1.3
# perceptual_sensitivity  -0.17 0.64  0.03 0.45 0.55 1.1
# sadness                  0.52 0.42  0.08 0.45 0.55 2.0
# shyness                  0.16 0.10 -0.52 0.31 0.69 1.3
#
# ...

# %%
model <- fa(features,4,rotate='varimax')
model
# Out:
# Factor Analysis using method =  minres
# Call: fa(r = features, nfactors = 4, rotate = "varimax")
# Standardized loadings (pattern matrix) based upon correlation matrix
#                           MR1   MR3  MR2   MR4   h2   u2 com
# activity_level           0.39  0.67 0.02  0.07 0.60 0.40 1.6
# anger_frustration        0.88  0.09 0.03  0.13 0.80 0.20 1.1
# attention_focusing      -0.46 -0.34 0.31 -0.02 0.42 0.58 2.7
# discomfort               0.49 -0.01 0.25  0.37 0.44 0.56 2.4
# soothability            -0.74 -0.12 0.23  0.07 0.63 0.37 1.3
# fear                     0.11 -0.01 0.16  0.69 0.52 0.48 1.2
# high_intensity_pleasure  0.40  0.45 0.37 -0.21 0.54 0.46 3.4
# impulsivity              0.30  0.76 0.01  0.10 0.67 0.33 1.4
# inhibitory_control      -0.53 -0.42 0.41 -0.08 0.63 0.37 2.9
# low_intensity_pleasure  -0.08  0.10 0.66  0.29 0.53 0.47 1.4
# perceptual_sensitivity   0.03 -0.04 0.71  0.09 0.51 0.49 1.0
# sadness                  0.55  0.10 0.20  0.29 0.44 0.56 1.9
# ...

# %%
model <- fa(features,5,rotate='varimax')
model
# Out:
# Factor Analysis using method =  minres
# Call: fa(r = features, nfactors = 5, rotate = "varimax")
# Standardized loadings (pattern matrix) based upon correlation matrix
#                           MR1   MR3  MR2   MR5   MR4   h2     u2 com
# activity_level           0.53  0.58 0.11 -0.03  0.12 0.63 0.3664 2.2
# anger_frustration        0.82 -0.05 0.13  0.25  0.13 0.78 0.2210 1.3
# attention_focusing      -0.53 -0.26 0.25 -0.11 -0.02 0.42 0.5783 2.1
# discomfort               0.39 -0.09 0.28  0.23  0.35 0.41 0.5855 3.6
# soothability            -0.76  0.01 0.14 -0.14  0.04 0.62 0.3809 1.1
# fear                     0.05 -0.02 0.15  0.10  0.76 0.61 0.3860 1.1
# high_intensity_pleasure  0.42  0.36 0.42  0.07 -0.17 0.52 0.4839 3.3
# impulsivity              0.44  0.67 0.08  0.03  0.11 0.65 0.3466 1.8
# inhibitory_control      -0.66 -0.31 0.31 -0.03 -0.10 0.64 0.3632 2.0
# low_intensity_pleasure  -0.17  0.11 0.63  0.12  0.26 0.51 0.4870 1.7
# ...
